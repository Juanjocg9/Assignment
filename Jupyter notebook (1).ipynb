# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b> Juan Jose Canuto Gil </b> <br>
# Robotics Engineer

# %% [markdown]
# <i> I am interested in data science because it has a lot of potential in the robotics field </i>

# %% [markdown]
# <h3> The next code line shows a simple mathematic operation <h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |

# %% [markdown]
# - Bullet 1
# - Bullet 2
# - Bullet 3

# %% [markdown]
# [La Vanguardia](https://www.lavanguardia.com/)
